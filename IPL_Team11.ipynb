# %% [markdown]
# # Running the below cell will ask for a number corresponding to a team and on entering the number, the result will show

# %%
import pandas as pd
import numpy as np
import random

Cleaned_df = pd.read_excel('Final_excel.xlsx')

Team_Dictionary = {1:"Chennai Super Kings", 2: "Delhi Capitals", 3: "Kings XI Punjab",4:"Kolkata Knight Riders", 5:"Mumbai Indians",6:"Rajasthan Royals",7: "Royal Challengers Bangalore",8:"Sunrisers Hyderabad"}

selection = int(input("Enter a number based on team :"))


team_name = Team_Dictionary.get(selection)
team_df = Cleaned_df[Cleaned_df['Team']== team_name]  

def Predict_team_11(team):
    A = list(i for i, j in team_df[team_df['IsCaptain']=='Captain'].iterrows())
    B = list(i for i, j in team_df[(team_df['Playing_Role']=='Opening batsman')|(team_df['Playing_Role']=='Top-order batsman')|(team_df['Playing_Role']=='Batsman')|(team_df['Playing_Role']=='Middle-order batsman')].iterrows())
    C = list(i for i, j in team_df[(team_df['Playing_Role']=='Batting allrounder')|(team_df['Playing_Role']=='Bowling allrounder')].iterrows())
    D = list(i for i, j in team_df[team_df['Playing_Role']=='Bowler'].iterrows())
    E = list(i for i, j in team_df[team_df['Playing_Role']=='Wicketkeeper batsman'].iterrows())
    
    My_team_11_index = []

    while len(My_team_11_index)==0:
        samples = []
        samples.append((sorted(random.sample(A, 1))))

        if A[0] in B:
            B.remove(A[0])
            samples.append((sorted(random.sample(B, 3))))
        else:
            samples.append((sorted(random.sample(B, 3))))

        if team_df.loc[A]['Playing_Role'].item()!='Wicketkeeper batsman':
            samples.append((sorted(random.sample(E, 1))))
            samples.append((sorted(random.sample(C, 2))))
        else:  
            samples.append((sorted(random.sample(C, 3))))

        samples.append((sorted(random.sample(D, 4))))

        samples = [j for i in samples for j in i]

        s = team_df.loc[samples].groupby('IsOverseasPlayer')['IsOverseasPlayer'].count()
        t = team_df.loc[samples].groupby('IsUncapped')['IsUncapped'].count()
        try:
            if s['Overseas Player']==4:
                k = 5 if team == 'Kolkata Knight Riders' else 4
                if t['Uncapped']<k:
                    My_team_11_index = samples
        except KeyError:
            continue
    return team_df.loc[My_team_11_index]


Predict_team_11(team_name)
# Out:
# Enter a number based on team :4
#                      Team      Player_Name IsCaptain        Age  \
# 69  Kolkata Knight Riders   Dinesh Karthik   Captain  34.550685
# 77  Kolkata Knight Riders      Eoin Morgan        No  33.273973
# 86  Kolkata Knight Riders     Shubman Gill        No  20.279452
# 89  Kolkata Knight Riders   Rahul Tripathi        No  28.800000
# 74  Kolkata Knight Riders      Chris Green        No  26.216438
# 80  Kolkata Knight Riders     Sunil Narine        No  31.567123
# 85  Kolkata Knight Riders      Shivam Mavi        No  21.063014
# 73  Kolkata Knight Riders  Lockie Ferguson        No  28.517808
# 75  Kolkata Knight Riders    Kuldeep Yadav        No  25.013699
# 81  Kolkata Knight Riders  Prasidh Krishna        No  23.830137
# 84  Kolkata Knight Riders  Sandeep Warrier        No  28.709589
#
#             Playing_Role   Batting_style           Bowling_style  \
# 69  Wicketkeeper batsman  Right-hand bat      Right-arm offbreak
# 77  Middle-order batsman   Left-hand bat        Right-arm medium
# 86       Opening batsman  Right-hand bat      Right-arm offbreak
# 89     Top-order batsman  Right-hand bat        Right-arm medium
# 74    Bowling allrounder  Right-hand bat      Right-arm offbreak
# 80    Bowling allrounder   Left-hand bat      Right-arm offbreak
# 85    Bowling allrounder  Right-hand bat   Right-arm fast-medium
# 73                Bowler  Right-hand bat          Right-arm fast
# 75                Bowler   Left-hand bat  Slow left-arm chinaman
# 81                Bowler  Right-hand bat   Right-arm medium-fast
# 84                Bowler  Right-hand bat        Right-arm medium
#
#    IsOverseasPlayer IsUncapped
# 69               No         No
# 77  Overseas Player         No
# 86               No         No
# 89               No   Uncapped
# 74  Overseas Player         No
# 80  Overseas Player         No
# 85               No   Uncapped
# 73  Overseas Player         No
# 75               No         No
# 81               No   Uncapped
# 84               No   Uncapped
